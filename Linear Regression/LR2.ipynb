# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("homeprices.csv")
dataset
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000], dtype=int64)

# %%
dataset.shape
# Out:
# (5, 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)
x_train,y_train,x_test,y_test
# Out:
# (array([[3000],
#         [3600],
#         [4000]], dtype=int64),
#  array([565000, 680000, 725000], dtype=int64),
#  array([[3200],
#         [2600]], dtype=int64),
#  array([610000, 550000], dtype=int64))

# %%
reg=LinearRegression()
reg.fit(x,y)
t=reg.predict(x)
t
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
import matplotlib.pyplot as pl
x,y
# Out:
# (array([[2600],
#         [3000],
#         [3200],
#         [3600],
#         [4000]], dtype=int64),
#  array([550000, 565000, 610000, 680000, 725000], dtype=int64))

# %%
pl.scatter(x,y, color="red")
pl.plot(x,t, color="blue")
pl.title("Linear Regression House Area vs Prices")
pl.xlabel("Area")
pl.ylabel("Prices")
pl.show()

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(t,y)
print ("Mean squared error is =",mse)
y,t
# Out:
# Mean squared error is = 186815068.4931509
# (array([550000, 565000, 610000, 680000, 725000], dtype=int64),
#  array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#         723767.12328767]))

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
pl.scatter(x,y, color="red")
pl.plot(x,y, color="blue")
pl.title("Linear Regression House Area vs Prices")
pl.xlabel("Area")
pl.ylabel("Prices")
pl.show()

# %%
value_to_predict = 3600

# Reshape the input to be a 2D array
input_data = np.array([[value_to_predict]])
prediction = reg.predict(input_data)
print ("Predicted value is ", prediction)
# Out:
# Predicted value is  [669452.05479452]

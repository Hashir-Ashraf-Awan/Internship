# %%
import pandas as pd
import numpy as np

dataset=pd.read_csv("dataset.csv")
dataset.head

x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values

dataset.shape
# Out:
# (30, 2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression # type: ignore
from sklearn.metrics import mean_squared_error
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train,x_test,y_train,y_test
# Out:
# (array([[ 7.9],
#         [ 2.9],
#         [ 5.1],
#         [ 3.2],
#         [ 4.5],
#         [ 8.2],
#         [ 6.8],
#         [ 1.3],
#         [10.5],
#         [ 3. ],
#         [ 2.2],
#         [ 5.9],
#         [ 6. ],
#         [ 3.7],
#         [ 3.2],
#         [ 9. ],
#         [ 2. ],
#         [ 1.1],
#         [ 7.1],
#         [ 4.9],
#         [ 4. ]]),
#  array([[ 1.5],
#         [10.3],
#         [ 4.1],
#         [ 3.9],
#         [ 9.5],
#         [ 8.7],
#         [ 9.6],
#         [ 4. ],
#         [ 5.3]]),
#  array([101303,  56642,  66029,  64445,  61111, 113812,  91738,  46205,
#         121872,  60150,  39891,  81363,  93940,  57189,  54445, 105582,
#          43525,  39343,  98273,  67938,  56957], dtype=int64),
#  array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55789,
#          83088], dtype=int64))

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
t=reg.predict(x_test)
t #predictedd
x_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7],
#        [ 9.6],
#        [ 4. ],
#        [ 5.3]])

# %%
y_test #actual values
# Out:
# array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55789,
#         83088], dtype=int64)

# %%
import matplotlib.pyplot as pl

# %%
pl.scatter(x_train,y_train, color="red")
pl.plot(x_train,reg.predict(x_train), color="blue")
pl.title("Linear Regression Salary vs Experiences")
pl.xlabel("Years of Experiece")
pl.ylabel("Salary")
pl.show()

# %%
mse=mean_squared_error(y_test,t)
print("Mean Squared Error is ", mse)
# Out:
# Mean Squared Error is  23379533.604531437

# %%
y_test
# Out:
# array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55789,
#         83088], dtype=int64)

# %%
t
# Out:
# array([ 40817.75673712, 123188.24906078,  65154.49310548,  63282.43646176,
#        115700.0224859 , 108211.79591102, 116636.05080776,  64218.46478362,
#         76386.83296779])
